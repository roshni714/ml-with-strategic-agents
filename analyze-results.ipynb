# %%
import pandas as pd
import numpy as np

# %%
df_ntypes_10 = pd.read_csv("results/challenge_none_n_types_10_n_1000000.csv")

# %%
df_ntypes_10
# Out:
#          n  d  n_types     sigma    q  seed  perturbation_s  \
# 0  1000000  2       10  3.411968  0.7     0             0.2
# 1  1000000  2       10  3.482621  0.7     1             0.2
# 2  1000000  2       10  3.316494  0.7     2             0.2
# 3  1000000  2       10  3.478472  0.7     3             0.2
# 4  1000000  2       10  3.275181  0.7     4             0.2
# 5  1000000  2       10  3.396843  0.7     5             0.2
# 6  1000000  2       10  2.951452  0.7     6             0.2
# 7  1000000  2       10  3.419998  0.7     7             0.2
# 8  1000000  2       10  2.850814  0.7     8             0.2
# 9  1000000  2       10  3.463803  0.7     9             0.2
#
#    perturbation_theta  opt_loss  opt_theta  final_loss  final_theta  \
# 0               0.025 -1.615662   1.218169   -1.482211          0.0
# 1               0.025 -1.604909   1.218169   -1.363440          0.0
# 2               0.025 -1.495283   1.346397   -1.303628          0.0
# ...

# %%
np.abs((df_ntypes_10["final_loss"]- df_ntypes_10["opt_loss"])).mean()
# Out:
# 0.18643495775888141

# %%
np.abs((df_ntypes_10["final_theta"]- df_ntypes_10["opt_theta"])).mean()
# Out:
# 1.243814234278408
